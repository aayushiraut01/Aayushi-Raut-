# %%
n = 5

for i in range(1, n + 1):
    # spaces
    for j in range(n - i):
        print(" ", end="")

    # stars
    for j in range(i):
        print("*", end="")

    print()

# %%
n = 5
i = 1

while i <= n:
    print(" " * (n - i) + "*" * i)
    i += 1
# Out:
#     *
#    **
#   ***
#  ****
# *****

# %%
n=7
i=1
while i <=n:
    print(" "*(n-i)+"*"*i)
    i=i+1
# Out:
#       *
#      **
#     ***
#    ****
#   *****
#  ******
# *******

# %%
n=4
i=1
while i <=n:
    print(" "*(n-i)+"*"*i)
    i=i+1
# Out:
#    *
#   **
#  ***
# ****

# %%
n=5
i=1
while i<=5:
    print("*"*i)
    i=i+1
# Out:
# *
# **
# ***
# ****
# *****

# %%
n = 5
i = 1

while i <= n:
    print(" " * (n - i) + "*" * (2 * i - 1))
    i = i + 1
# Out:
#     *
#    ***
#   *****
#  *******
# *********

# %%
n=10
i=1
while i <=n:
    print("*"*i)
    i=i+1
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********

# %%
n=10
i=1
while i <=n:
    print(" "*(n-i)+"*"*i)
    i=i+1
# Out:
#          *
#         **
#        ***
#       ****
#      *****
#     ******
#    *******
#   ********
#  *********
# **********

# %%
n=10
i=1
while i <=n:
    print(" "*(n-i)+"*"*(2*i-1))
    i=i+1
# Out:
#          *
#         ***
#        *****
#       *******
#      *********
#     ***********
#    *************
#   ***************
#  *****************
# *******************

# %%
i = 10

try:
    if i % 2 == 0:
        print(i)
except Exception as e:
    print(e)
# Out:
# 10

# %%
i=9
try:
    if i %2==0:
        print(i)
except Exception as e:
    print(e)

# %%
try:
    num1=int(input("eneter first number:"))
    num2=int(input("enter second number:"))
    result= num1/num2
    print(result)
except Exception as e:
    print(e)
# Out:
# eneter first number: 20
# enter second number: 0
# division by zero

# %%
try:
    num1 = int(input("Enter first number: "))
    num2 = int(input("Enter second number: "))

    result = num1 / num2
    print("Result:", result)

except ValueError:
    print("Please enter numbers only.")

except ZeroDivisionError:
    print("Cannot divide by zero.")

# %%
numbers = [10, 20, 30, 40, 50]

try:
    index = int(input("Enter index: "))

    print(numbers[index])
    

except ValueError:
    print("plese enter correct value")

except IndexError:
    print("enter correct index")
# Out:
# Enter index:  abs
# plese enter correct value

# %%
data = [1, 2, 2, 3, 4, 4, 4, 5]
data=set([1, 2, 2, 3, 4, 4, 4, 5])

# %%
data
# Out:
# {1, 2, 3, 4, 5}

# %%
data=[{1, 2, 3, 4, 5}]

# %%
data
# Out:
# [{1, 2, 3, 4, 5}]

# %%
data = [1, 2, 2, 3, 4, 4, 4, 5]

# Set conversion removes duplicates automatically
unique_data = list(set(data))

print(f"Unique List: {unique_data}")

# %%
data = [1, 2, 2, 3, 4, 4, 4, 5]
unique_data=list(set(data))
print(f"unique List: {unique_data}")
# Out:
# unique List: [1, 2, 3, 4, 5]

# %%
numbers = [5, 2, 5, 8, 2, 9, 8, 10, 5]
unique_data=list(set(numbers))
print(f"unique list: {unique_data}")
# Out:
# unique list: [2, 5, 8, 9, 10]

# %%
numbers_x = [10, 20, 30, 40, 10]
numbers_y = [75, 65, 35, 75, 30]
def lis(numbers_x):
    if numbers_x[0]==[4]: 
        return True
