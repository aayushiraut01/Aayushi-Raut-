# %% [markdown]
# # CONDITIONS

# %%
num = int(input())

if num > 10 :
    print("if block")

else:
    print("else block")
# Out:
#  9
# else block

# %%
num = int(input())

if num >= 10 :
    print("if block")

elif num == 20:
    print("elif block")

else:
    print("else block")
# Out:
#  9
# else block

# %%
number = 10
A = 10
B = 20
C = 30

if number == A:
    print("python-1")
elif number > B :
    print("python-2")
elif C > B:
    print("python-3")
else:
    print("i don't know")
# Out:
# python-1

# %%
number = 10
A = 10
B = 20
C = 30

if number == A:
    print("python-1")
elif number > B :
    print("python-2")
if C > B:
    print("python-3")
else:
    print("i don't know")
# Out:
# python-1
# python-3

# %%
number  = 10

if number == 11:
    print("number is equal")
elif number > 11:
    print("number is greater than 11")
    
if number < 11:
    print("number is less than 11")
# Out:
# number is less than 11

# %%
number  = 11

if number == 11:
    print("number is equal")
elif number > 11:
    print("number is greater than 11")
    
if number == 11:
    print("number is less than 11")

if number == 11:
    print("   ---")
# Out:
# number is equal
# number is less than 11
#    ---

# %%
mark = int(input("Enter the mark "))

if mark < 0 or mark > 100: 
    print("Invalid marks are entered!")
    
elif mark >= 0 and mark < 35 :
    print("Sorry you failed!")
    
elif mark >= 36 and mark <= 60:
    print("You passed in second class")
    
elif mark >= 61 and mark <= 80 :
    print("You passed in first class")
    
elif mark >= 91 and mark <= 100:
    print("you are in top 10 list")
    
else :
    print("You got distinction!")
# Out:
# Enter the mark  92
# you are in top 10 list

# %%
number1 = int(input("Enter first number \n"))
number2 = int(input("Enter second number \n"))

if number1 == number2:
    print("Both numbers are same")
else:
    if number1 > number2:
        print("First number is bigger than second")
    else:
        print("First number is smaller than second")
# Out:
# Enter first number
#  899
# Enter second number
#  34
# First number is bigger than second

# %%
number = int(input("Enter the number "))

if number % 2 == 0 :   # if entered number is even then only message is shown to the user
    print(number ," is even number") 
else :
    print(number ," is odd number")
# Out:
# Enter the number  6
# 6  is even number

# %%
length_in_cm = input("Enter the lenght in centimeter ")

length_in_cm = float(length_in_cm)
    
if length_in_cm < 0 :
    print("You have entered negative value. ")
else:
    length_in_inches = length_in_cm / 2.54
    print(length_in_cm, " cm = ", length_in_inches, " inches")
# Out:
# Enter the lenght in centimeter  78
# 78.0  cm =  30.708661417322833  inches

# %%
# Password and Username Checking
username = input("Enter your username: ")
password = input("Enter your password: ")


if username == "admin":
    if password == "password":
        print("Login successful! Welcome, admin.")
    elif password == "12345":
        print("Weak password. Please reset your password.")
    else:
        print("Incorrect password. Please try again.")
else:
    if username == "guest":
        if password == "guest":
            print("Login successful! Welcome, guest.")
        else:
            print("Incorrect password. Please try again.")
    else:
        print("Unknown user. Please try again.")
# Out:
# Enter your username:  guest
# Enter your password:  12345
# Incorrect password. Please try again.

# %%
numb= 10
A= 10 
B= 20 
C= 30 
if numb < C :
         print("numb is smaller than C")
if numb < B:
         print( "numb is smaller than C" )

else : 
     print("incorrect output)
# Out:
# numb is smaller than C
# numb is smaller than C

# %%
student_marks= int(input("enter the marks "))

if student_marks >=35:
    print("they passed in second class")
if student_marks<=35:
    print("student failed")
elif student_marks ==20:
    print("elif block")

else:
    print("distinction")
# Out:
# enter the marks  20
# student failed

# %%
num= int(input("enter the number"))
if num%2==0 or num%3==0 or num%7==0 or num%5==0:
     print("not prime")

else:
     print("prime number")
# Out:
# enter the number 19
# prime number

# %%
var= input("enter the vowel")

if var == "a, e, i , o, u":
     print("vowel")
    

elif  var == "consonent":
     print("consonent")
    

else:
     print("not appropriate code")
# Out:
# enter the vowel a, e , i , o ,u
# not appropriate code

# %%
var= input("enter a letter")

if var == "aeiou":
    print("vowel")

elif var == "consonent":
    print("consonent")


else:
    print("inappropriate letter")
# Out:
# enter a letter a
# inappropriate letter

# %%
TERNARY OPERATORS

# %%
num = int(input())

if num%2 == 0:
    print("even")
else:
    print("odd")
# Out:
#  2
# even
