# %% [markdown]
# # CONDITIONS

# %%
var= input("Enter a letter")

if var in "aeiou":
    print("vowel")

    

else:
    print("consonent")
# Out:
# Enter a letter a
# vowel

# %%
numb= int(input("Enter a number"))

if numb%2==0 or numb%3==0 or numb%5==0 or numb%7==0:
    print("not prime")

else:
    print("prime number")
# Out:
# Enter a number 37
# prime number

# %%
student_marks= 78

if student_marks>=90:
    print("Excellent")

elif student_marks>75 and student_marks<89:
    print("Good")

elif student_marks>50 and student_marks<50:
    print("Average")

else:
    print("fail")
# Out:
# Good

# %%
age=18

if age>=18:
    print("eligiable to vote ")

else:
    print("not eligiable to vote ")
# Out:
# eligiable to vote

# %%
age= 18

if age>=18:
    print("eligible to vote")

elif age >= 13 and age <=17:
    print("teenager")

else:
    print("child")
# Out:
# eligible to vote

# %%
marks= 92

if marks >=90:
    print("A grade")

elif marks >= 75 and marks <=89:
    print("B grade")

elif 50>= marks <=75:
    print("C grade")

else:
    print("Fail")
# Out:
# A grade

# %%
temp = 35

if temp > 40:
    print(" very hot")
elif temp> 30 and temp< 40:
    print("hot")
elif temp > 20 and temp< 29:
    print ("pleasant")
else:
    print("cold")
# Out:
# hot

# %%
var= input("enter a words ")

if var == "red":
    print("stop")
elif var== "yellow":
    print("get ready")
elif var == "green":
    print("go")
else:
    print("invalid signal")
# Out:
# enter a words  red
# stop

# %%
num= int(input ("enter a num"))

if num< 0:
    print("Negative")
elif num>0:
    print("positive")
else:
    print("zero")
# Out:
# enter a num 783
# positive

# %%
age= 18
if age>= 18:
    print("adult")
elif age>=13 and age<=19:
    print("teenager")
else:
    print("child")
# Out:
# adult

# %%
var=input("enter a password")
if var== "python123":
    print("login successfully")
else:
    print("try again letter")
# Out:
# enter a password python123
# login successfully

# %%
var= input("enter the word")
if var=="red":
    print("stop")
elif var=="yellow":
    print("get ready")
else:
    print("go")
# Out:
# enter the word nice
# go

# %%
var=input("enter a day")
if var in ("monday, tuesday, wednesday, thrusday, friday"):
    print("working days")
elif var in ("saturday, sunday"):
    print("holiday")
else:
    print("invalid day")
# Out:
# enter a day sunday
# holiday

# %%
marks= int(input("enter the marks"))
if marks>= 90:
    print("A grade")
elif marks >=75 and marks <=89:
    print("B grade")
elif marks >=50 and marks <=74:
    print("C grade")
elif marks <50:
    print("Fail")
else:
    print("Invalid marks")
# Out:
# enter the marks 90
# A grade

# %%
var=input("enter a username")
password= int(input("enter a password"))
if var=="admin":
    if password==12345:
        print("login successfully")
elif var=="Admin":
    if password==123456:
        print("incorrect password")
else:
    print("try again letter")
# Out:
# enter a username Admin
# enter a password 123456
# incorrect password

# %%
purchaser_amount=int(input("amount"))
customer_membership=(input("discount"))

if purchaser_amount>=1000:
    if customer_membership=="yes":
        
        print("20% discount")
    else:
        print("10% discount")

else :
    print("no discount")
# Out:
# amount 1000
# discount yes
# 20% discount

# %%
purchaser_amount=int(input("amount"))
customer_membership= input("discount")

if purchaser_amount>=1000:
    if customer_membership=="yes":
         print("20% discount")
    else:
        print("10% discount")

else :
    print("no discount")
# Out:
# amount 1000
# discount yes
# 20% discount

# %%
age=18
ID= "yes"
if age>=18:
    if ID =="yes":
        print("tickets issued")
    else:
        print("bring ID")
else:
    print("not eligible")
# Out:
# tickets issued

# %%
account_balance=int(input("enter balance"))
amount_withdrawl=int(input("withdrawl balance"))
if amount_withdrawl <= account_balance:
    if amount_withdrawl %100==0:
        print("withdrawl successfully")
    else:
        print("enter amount in multiples of hundered")
else:
    print("insufficient balance")
# Out:
# enter balance 5000
# withdrawl balance 1200
# withdrawl successfully
