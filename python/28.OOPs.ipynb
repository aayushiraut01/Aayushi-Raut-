# %%
class publicExample:
    def __init__(self):
        self.public_var="I'm Public attribute"
    def Public_method(self):
        return "This is public method"

# %%
obj=publicExample()

# %%
obj.Public_method()
# Out:
# 'This is public method'

# %%
class Protected_example:
    company="TCS"
    def __init__(self):
        self.protected="I'm protected"
    def _protected_method(self):
        return "I'm protected"
    def access_protected(self):
        return self.protected

# %%
obj = Protected_example()

# %%
obj.access_protected()
# Out:
# "I'm protected"

# %%
print(obj.access_protected())
# Out:
# I'm protected

# %%
obj.protected
# Out:
# "I'm protected"

# %%
obj.company
# Out:
# 'TCS'

# %%
class private:
    company="TCS"
    def __init__(self):
        self.private_var="I'm private"
    def __private_method(self):
        return "this is private method"
    def private_access(self):
        return self.private_var+"-"+ self.__private_method()

# %%
obj=private()

# %%
obj.private_access()
# Out:
# "I'm private-this is private method"

# %%
obj.private_var
# Out:
# "I'm private"

# %%
class calculator:
    def __init__(self,value):
        self._value=value
    def add(self,num):
        self._value+=num
        return self.value
    def get_value(self):
        return self.value

# %%
cal=calculator(1000)

# %%
cal.add(500)
# Out:
# 1500

# %%
cal.get_value()
# Out:
# 1500

# %%
class calculator:
    def __init__(self,value):
        self._value=value
    def add(self,num):
        self._value+=num
        return self._value
    def get_value(self):
        return self._value

# %%
obj=calculator(1000)

# %%
class maths:
    @staticmethod
    def add(a,b):
        
        return a+b
    @staticmethod
    def sub(a,b):
        return a-b

# %%
obj = maths()

# %%
obj.add(30,67)
# Out:
# 97

# %%
obj.sub(77,67)
# Out:
# 10

# %%
class person:
    name = "amit"
    surname="kumar"
    yob= 1993
    def age(self,current):
        
        self.age=current-self.yob
        return self.age

# %%
obj=person()

# %%
obj.age(2026)
# Out:
# 33

# %%
class employee(person):
    name="sunil"
    surname="singh"
    yob=1997

# %%
obj1=employee()

# %%
obj1.
