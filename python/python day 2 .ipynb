# %% [markdown]
# # day2

# %%
variable=("hello")

# %%
a, b, c, d = 10, 20, 30 ,40

# %%
a
# Out:
# 10

# %%
b
# Out:
# 20

# %%
c
# Out:
# 30

# %%
d
# Out:
# 40

# %%
a+b
# Out:
# 30

# %%
a-b
# Out:
# -10

# %%
b-a
# Out:
# 10

# %%
c/a
# Out:
# 3.0

# %%
b*a
# Out:
# 200

# %%
c%a
# Out:
# 0

# %%
d%a
# Out:
# 0

# %%
x,y= 3,19

# %%
y/x
# Out:
# 6.333333333333333

# %%
y//x
# Out:
# 6

# %%
y%x
# Out:
# 1

# %%
m, n = 2, 20

# %%
m%n
# Out:
# 2

# %%
m/n
# Out:
# 0.1

# %%
m+n
# Out:
# 22

# %%
m-n
# Out:
# -18

# %%
n-m
# Out:
# 18

# %%
m/n
# Out:
# 0.1

# %%
n/m
# Out:
# 10.0

# %%
n//m
# Out:
# 10

# %%
n%m
# Out:
# 0

# %%
n**m
# Out:
# 400

# %%
m*n
# Out:
# 40

# %%
m<n
# Out:
# True

# %%
m>n
# Out:
# False

# %%
m!=n
# Out:
# True

# %%
m==n
# Out:
# False

# %%
j, k = 30, 60

# %%
j<=k
# Out:
# True

# %%
j>=k
# Out:
# False

# %% [markdown]
# Logical Operatiors

# %%
j and k
# Out:
# 60

# %%
j or k
# Out:
# 30

# %% [markdown]
# ## Type Casting

# %%
# INTEGER TO STRING 
rollno = ("1,2,3,4,5")

# %%
type(rollno)
# Out:
# str

# %%
# Interger to Float 
rollno=(3.11,3.22,3.33)

# %%
type(rollno)
# Out:
# tuple

# %%
a=10
b=float(a)

# %%
type(b)
# Out:
# float

# %%
a= 3.12, 3.14 , 31.4

# %%
type(a)
# Out:
# tuple

# %%
a= 3.13

# %%
type(a)
# Out:
# float

# %%
# Float to integer ( add the int())
a=10.9
b=int(a)

# %%
type(b)
# Out:
# int

# %%
# string to integer ( add the"")
a= "25"

# %%
type(a)
# Out:
# str

# %%
# BOOLEAN (while Truw and False it is imp to write T&F capital  )
a = True

# %%
type(a)
# Out:
# bool

# %%
b = False

# %%
type(b)
# Out:
# bool

# %%
list=[1,2,3,3,4]

# %%
type(list)
# Out:
# list

# %%
tuple=(2,3,4,5,7,8)

# %%
type(tuple)
# Out:
# tuple

# %%
# in set no alphabets 
set={1,3, 6}

# %%
type(set)
# Out:
# set

# %%
dic={1:a, b:2}

# %%
type(dic)
# Out:
# dict
