# %%
 var=("hello world")

# %% [raw]
# print(var)

# %%
print(var)
# Out:
# hello world

# %%
print("hello \nworld")
# Out:
# hello
# world

# %%
print("\t hello world")
# Out:
# 	 hello world

# %%
print("hello \tworld")
# Out:
# hello 	world

# %%
print("\nhello world")
# Out:
# hello world

# %%
S1=("""Connect with MongoDB experts, AI innovators, 
and tech leaders and get the skills you need to build
great application experiences for a new generation of users""")

# %%
print(S1)
# Out:
# Connect with MongoDB experts, AI innovators,
# and tech leaders and get the skills you need to build
# great application experiences for a new generation of users

# %%
numb1="1947"

# %%
print(numb1)
# Out:
# 1947

# %%
numb1="'1947'"

# %%
print(numb1)
# Out:
# '1947'

# %%
numb2='"1947"'

# %%
print(numb2)
# Out:
# "1947"

# %% [markdown]
# # STRING FORMAT

# %%
# %s , %d , %.f
name=(" Aayushi Raut") 
age = 22
subject = ("Data science")

# %%
print("my name is %s, my age is %d , my subject is %s"% (name, age , subject  ))
# Out:
# my name is  Aayushi Raut, my age is 22 , my subject is Data science

# %%
print("my name is %s , my age is %d, version is  %.2f" % (name, age , lang))

# %%
name= "Aayushi Raut"
age= 22
subject= "Data Science"
lang= 3.14

# %%
print("my name is %s, my age is %d , my subject is %s , version is %f" % (name, age , subject , lang ))
# Out:
# my name is Aayushi Raut, my age is 22 , my subject is Data Science , version is 3.140000

# %%
name= "Arush Raut" 
age = 19 
proffession= "student"
lang1= 1.34
lang= 3.14

# %%
print("my name is %s , my age is %d , my proffesion is %s , version 1 is %.2f , version 2 is %.f "% (name, age , proffession, lang1 ,lang ))
# Out:
# my name is Arush Raut , my age is 19 , my proffesion is student , version 1 is 1.34 , version 2 is 3

# %%
name= "Aayushi Raut"
age= 22
subject= "Data Science"
lang= 3.14

# %%
print ("my name is {}, my age is {}, my subject is {}, version is {} ". format(name , age , subject , lang))
# Out:
# my name is Aayushi Raut, my age is 22, my subject is Data Science, version is 3.14

# %%
name = "Arush Raut" 
age = 19 
proffession = "student"
lang1 = 1.34
lang = 3.14

# %%
print("my name is {} , my age is {}, my proffession is {} , version 1 is {}, version 2 is {}" .format ( name, age, proffession, lang1, lang))
# Out:
# my name is Arush Raut , my age is 19, my proffession is student , version 1 is 1.34, version 2 is 3.14

# %%
name = "Yogita Raut "
age = 25
proffession = "trainer"
lang = 3.12

# %%
print(" my name is {},my age is {}, my proffession is {} , version is {} " .format( name, age , proffession, lang))
# Out:
#  my name is Yogita Raut ,my age is 25, my proffession is trainer , version is 3.12

# %%
print( "my name is %s , my age is %d , my proffession is %s , version is %.3f " % ( name , age , proffession, lang))
# Out:
# my name is Yogita Raut  , my age is 25 , my proffession is trainer , version is 3.120

# %%
print(name)
print(age)
print(proffession)
print(lang)
# Out:
# Yogita Raut
# 25
# trainer
# 3.12

# %%
print(name, end = "")
print(age, end ="")
print(proffession, end ="")
print(lang )
# Out:
# Yogita Raut 25trainer3.12

# %%
print(name, end = "")
print( age, end ="")
print(proffession, end ="")
print(lang )
# Out:
# Yogita Raut 25trainer3.12

# %%
var = ""' this is my first variable'""

# %%
print(var)
# Out:
#  this is my first variable

# %% [markdown]
# ## STRING OPERATORS

# %% [markdown]
# ### CONCATENATION

# %%
# JOINING OR ADDITION OF THE SCENTENCE 
name=" Aayushi" 
surname=" Raut "

# %%
print(name+ " " + surname)
# Out:
#  Aayushi  Raut

# %%
print (var + "" + name  + surname )
# Out:
#  this is my first variable Aayushi Raut

# %%
name = "Yogita Raut "
age = 25
proffession = "trainer"
lang = 3.12

# %%
print( name + "" + proffession  )
# Out:
# Yogita Raut trainer

# %% [markdown]
# #### REPETATION

# %%
name*4
# Out:
# 'Yogita Raut Yogita Raut Yogita Raut Yogita Raut '

# %%
age*4
# Out:
# 100

# %%
lang*4
# Out:
# 12.48

# %%
proffession*9
# Out:
# 'trainertrainertrainertrainertrainertrainertrainertrainertrainer'

# %%
proffession  *  9
# Out:
# 'trainertrainertrainertrainertrainertrainertrainertrainertrainer'

# %% [markdown]
# #### INDEXING

# %%
var
# Out:
# ' this is my first variable'

# %%
var[6]
# Out:
# 'i'

# %%
var[0]
# Out:
# ' '

# %%
var[1]
# Out:
# 't'

# %%
numb= 1,2,3,5,7,9,6,4,3

# %%
numb[1]
# Out:
# 2

# %%
var[3]
# Out:
# 'i'

# %%
numb[3]
# Out:
# 5

# %%
numb[-3]
# Out:
# 6

# %% [markdown]
# ##### SLICING

# %%
var
# Out:
# ' this is my first variable'

# %%
var[1: 5]
# Out:
# 'this'

# %%
var[0: 5]
# Out:
# ' this'

# %%
var[1:6]
# Out:
# 'this '

# %%
var[1:7]
# Out:
# 'this i'

# %%
var[0:1 ]
# Out:
# ' '

# %%
var[2:10]
# Out:
# 'his is m'

# %%
var[1:15: 2]
# Out:
# 'ti sm i'

# %%
var[1 :15: -2]
# Out:
# ''

# %% [markdown]
# ##### MUTATION

# %% [markdown]
# # CHANGES

# %%
var[5]
# Out:
# ' '

# %%
var[6]
# Out:
# 'i'

# %%
var= (" this is my frist string")

# %%
var
# Out:
# ' this is my frist string'

# %%
['S']
print(var)
# Out:
# ['S']

# %%
l1="Aayushi Raut"

# %% [markdown]
# #

# %%
l1
# Out:
# 'Aayushi Raut'

# %% [markdown]
# #

# %%
l1.upper()
# Out:
# 'AAYUSHI RAUT'

# %%
l1.lower()
# Out:
# 'aayushi raut'

# %% [markdown]
# l1

# %%
l1.capitalize()
# Out:
# 'Aayushi raut'

# %%
l1.title()
# Out:
# 'Aayushi Raut'

# %%
l1.swapcase()
# Out:
# 'aAYUSHI rAUT'

# %%
l1.center(90)
# Out:
# '                                       Aayushi Raut                                       '

# %% [markdown]
# l1

# %%
l1.isalpha()
# Out:
# False

# %%
l2=("white, red , blue")

# %%
l2
# Out:
# 'white, red , blue'

# %%
l2.isalpha()
# Out:
# False

# %%
l3= " Aayushi"

# %%
l3.isalpha()
# Out:
# False

# %%
l4="Raut"

# %%
l4.isalpha()
# Out:
# True

# %%
l5="Aayushiraut"

# %%
l5.isalpha()
# Out:
# True

# %%
l1
# Out:
# 'Aayushi Raut'

# %%
l1.isspace()
# Out:
# False

# %%
l2.isspace()
# Out:
# False

# %%
l6=" "

# %%
l6.isspace()
# Out:
# True

# %%
l7=" red,            blue            , orange "

# %%
l7
# Out:
# ' red,            blue            , orange '

# %%
l7.isspace()
# Out:
# False

# %%
l1
# Out:
# 'Aayushi Raut'

# %%
l1.islower()
# Out:
# False

# %%
l2.isupper()
# Out:
# False

# %%
l1.startswith("Aa")
# Out:
# True

# %%
l2.startswith("R")
# Out:
# False

# %%
l2.startswith(" red")
# Out:
# False

# %%
l2="red, blue,orange"

# %%
l2.startswith("red")
# Out:
# True

# %%
l2.startswith("r")
# Out:
# True

# %%
l2.endswith("e")
# Out:
# True

# %%
l2
# Out:
# 'red, blue,orange'

# %%
l2.count("e")
# Out:
# 3

# %%
l1.count("A")
# Out:
# 1

# %%
l1.index("a")
# Out:
# 1

# %%
l1.find("a")
# Out:
# 1

# %%
l1.find("A")
# Out:
# 0

# %%
l1.find("y")
# Out:
# 2

# %%
l1.find("z")
# Out:
# -1

# %%
l1.find("g")
# Out:
# -1

# %%
l1.rfind("i")
# Out:
# 6

# %%
l1.rfind("A")
# Out:
# 0

# %%
l1.rfind("a")
# Out:
# 9

# %%
l1.rfind("t")
# Out:
# 11

# %%
l1.isnumeric()
# Out:
# False

# %%
l3="Aayushu=i , 22 , raut "

# %%
l3.isnumeric()
# Out:
# False

# %%
l3="1,2,3,4,5"

# %%
l3.isnumeric()
# Out:
# False

# %%
l4="123"

# %%
l4.isnumeric()
# Out:
# True

# %%
l1
# Out:
# 'Aayushi Raut'

# %%
l1.removeprefix("yu")
# Out:
# 'Aayushi Raut'

# %%
l1.removeprefix("Aa")
# Out:
# 'yushi Raut'

# %%
l1.removesuffix("ut")
# Out:
# 'Aayushi Ra'

# %%
l1.replace("Raut", "Ki")
# Out:
# 'Aayushi Ki'

# %% [markdown]
# #

# %%
l1.partition("Raut")
# Out:
# ('Aayushi ', 'Raut', '')

# %%
l1.partition("Aayushi")
# Out:
# ('', 'Aayushi', ' Raut')

# %%
l1.split("Aayushi")
# Out:
# ['', ' Raut']

# %%
l1.partition("and")
# Out:
# ('Aayushi Raut', '', '')

# %%
l1.split("and")
# Out:
# ['Aayushi Raut']

# %%
l1.partition("Raut")
# Out:
# ('Aayushi ', 'Raut', '')

# %%
l1.rpartition("Aayushi")
# Out:
# ('', 'Aayushi', ' Raut')

# %%
l2
# Out:
# 'red, blue,orange'

# %%
l2.rpartition("orange")
# Out:
# ('red, blue,', 'orange', '')

# %%
l2.rpartition("blue")
# Out:
# ('red, ', 'blue', ',orange')

# %%
l1.strip()
# Out:
# 'Aayushi Raut'

# %%
l6=("string^^%&^*(")

# %%
l7=("&&%$&string")

# %%
l6.rstrip("^")
# Out:
# 'string^^%&^*('

# %%
l7=("                     string")

# %%
l7.lstrip()
# Out:
# 'string'

# %%
l6.rstrip("^^%&^*(")
# Out:
# 'string'

# %%
l1
# Out:
# 'Aayushi Raut'

# %%
l1.join("Aayushi")
# Out:
# 'AAayushi RautaAayushi RautyAayushi RautuAayushi RautsAayushi RauthAayushi Rauti'

# %%
l1.join("and")
# Out:
# 'aAayushi RautnAayushi Rautd'

# %% [markdown]
# ##

# %%
l2
# Out:
# 'red, blue,orange'

# %%
"".join("l2")
# Out:
# 'l2'

# %% [raw]
# ""

# %%
"".join(l2)
# Out:
# 'red, blue,orange'

# %%
l1.isdigit()
# Out:
# False

# %%
l1
# Out:
# 'Aayushi Raut'

# %%
l1+""+l2
# Out:
# 'Aayushi Rautred, blue,orange'

# %%
l1*3
# Out:
# 'Aayushi RautAayushi RautAayushi Raut'

# %%
l1[5]
# Out:
# 'h'

# %%
l1[0:5:1]
# Out:
# 'Aayus'

# %% [markdown]
# # TUPLE

# %%
tuple=("Aayushi","Raut")

# %%
type(tuple)
# Out:
# tuple

# %%
colours=("hat", "bat", "cat")

# %%
fruits=("apple", "banana", "graphes")

# %%
colours + fruits
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 colours + fruits
#
# NameError: name 'colours' is not defined

# %%
colours=("hat", "bat", "cat")

# %%
type(colours)
# Out:
# tuple
