# %% [markdown]
# # FUNCTIONS

# %%
name=input("enter your name")
# Out:
# enter your name arush raut

# %%
print(name)
# Out:
# arush raut

# %%
age=input("enter your age")
# Out:
# enter your age 22

# %%
age
# Out:
# '22'

# %%
nationality=input("enter your nationality")
# Out:
# enter your nationality indian

# %%
nationality
# Out:
# 'indian'

# %%
# length
l1=(1,2,3,5,6,7,89,4,2,57,8,9,)

# %%
len(l1)
# Out:
# 12

# %%
l2=("aayushi, rohan,arush")

# %%
len(l2)
# Out:
# 20

# %%
l3=("a,b,c,d,e,f,g,h")

# %%
len(l3)
# Out:
# 15

# %%
l4=("1,2,3,4,5,6,7,8,9")

# %%
len(l4)
# Out:
# 17

# %%
range=(l4)

# %%
range
# Out:
# '1,2,3,4,5,6,7,8,9'

# %%
len("l3")
# Out:
# 2

# %%
len(l4)
# Out:
# 17

# %%
range=(l4)

# %%
range
# Out:
# '1,2,3,4,5,6,7,8,9'

# %% [raw]
# l1 = [2,3,4,5,6,8]

# %%
len(l1)
# Out:
# 12

# %%
students=(30,40,50)

# %%
all(students)
# Out:
# True

# %%
any(students)
# Out:
# True

# %%
l1=(1,2,3,4,5,6)

# %%
len(l1)
# Out:
# 6

# %%
range(6)
# Out:
# range(0, 6)

# %%
range(0,6,2)
# Out:
# range(0, 6, 2)

# %%
list[range(0,5,1)]
# Out:
# list[range(0, 5)]

# %% [markdown]
# l1

# %%
l1
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
len(l1)
# Out:
# 6

# %%
range(6)
# Out:
# range(0, 6)

# %%
list(range ( 0 , 6, 1 ))
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
l2= (2,3,4,5)

# %%
len(l2)
# Out:
# 4

# %%
range(4)
# Out:
# range(0, 4)

# %%
list(range (0 , 3 , 2))
# Out:
# [0, 2]

# %%
tuple(range(0,4,1))
# Out:
# (0, 1, 2, 3)

# %%
max(l2)
# Out:
# 5

# %%
l2
# Out:
# (2, 3, 4, 5)

# %%
min(l2)
# Out:
# 2

# %%
var= None

# %%
type(var)
# Out:
# NoneType

# %%
del(var)

# %%
var
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 var
#
# NameError: name 'var' is not defined

# %% [markdown]
# ASCII

# %%
chr(56)
# Out:
# '8'

# %%
chr(76)
# Out:
# 'L'

# %% [raw]
# chr(22)

# %% [raw]
# vyhdsh

# %%
chr(22)
# Out:
# '\x16'

# %%
ord("g")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 ord("g")
#
# TypeError: 'str' object is not callable

# %%
a=10

# %%
isinstance(a,int)
# Out:
# True

# %%
hat=("APPLE, BAT")

# %%
# to make it tuple add " " to every value as python sees them as one single value or elements 
isinstance(hat,tuple,)
# Out:
# False

# %%
var=("hello")

# %%
_=90

# %%
var
# Out:
# 'hello'

# %%
type(var)
# Out:
# str

# %%
num1=("1,2,3,4")

# %%
num1
# Out:
# '1,2,3,4'

# %%
type(num1)
# Out:
# str

# %%
numb=1,2,3,4

# %%
type(numb)
# Out:
# tuple

# %%
numb2=3.45,456.5,84.3

# %%
type(numb2)
# Out:
# tuple

# %%
numb= 3

# %%
type(numb)
# Out:
# int

# %%
numb3=837.389

# %%
type(numb3)
# Out:
# float

# %%
string=("aayushi, arush")

# %%
type(string)
# Out:
# str

# %%
string1=("aayushi", "raut")

# %%
type(string1)
# Out:
# tuple

# %%
numb=7+3j

# %%
type(7+3j)
# Out:
# complex

# %%
j=4

# %%
students=(37,7549,859)

# %%
type(students)
# Out:
# tuple

# %%
5>5
# Out:
# False

# %%
type
# Out:
# type

# %%
type(5>5)
# Out:
# bool

# %%
list=("bat, ball, cat")

# %%
type(list)
# Out:
# str

# %%
list=["bat, ball, cat"]

# %%
type(list)
# Out:
# list

# %%
list=("bat","ball")

# %%
type(list)
# Out:
# tuple

# %%
set={1,2,4,6,7,9}

# %%
type(set)
# Out:
# set

# %%
dic={}

# %%
type(dic)
# Out:
# dict

# %%
dict={1:"black", 2:"white"}

# %%
type(dict)
# Out:
# dict

# %%
set=[1,2,4,6,7,9]

# %%
type(set)
# Out:
# list

# %% [markdown]
# # OPERATORS

# %%
4+6
# Out:
# 10

# %%
4-5
# Out:
# -1

# %%
9/3
# Out:
# 3.0

# %%
3*3
# Out:
# 9

# %%
9%3
# Out:
# 0

# %%
9//3
# Out:
# 3

# %%
9**3
# Out:
# 729

# %%
9*3
# Out:
# 27

# %%
7>4 and 7<7
# Out:
# False

# %%
7958<854327 or 589< 87539
# Out:
# True

# %%
not True
# Out:
# False

# %% [markdown]
# ## TYPE CASTING

# %%
int
# Out:
# (1, 34, 6, 7, 6)

# %%
type(int)
# Out:
# tuple

# %%
int=455

# %%
type(int)
# Out:
# int

# %%
int=("637,399 ,8379 ")

# %%
type(int)
# Out:
# str

# %%
int=7399

# %%
float(int)
# Out:
# 7399.0

# %%
float=98.4
b=("float")

# %%
type(float)
# Out:
# float

# %%
mylist=("hyaiu fi,jhuwu wii,nir9  ,urfriu9 ,78438,jjaj ")

# %%
print(mylist)
# Out:
# hyaiu fi,jhuwu wii,nir9  ,urfriu9 ,78438,jjaj

# %%
name= input("enter your name")
# Out:
# enter your name Aayushi Raut

# %%
 type(mylist)
# Out:
# str

# %%
len(mylist)
# Out:
# 46

# %%
range(46)
# Out:
# range(0, 46)

# %%
range(0,45,1)
# Out:
# range(0, 45)

# %%
numb=(1,2,45,7,9,4,2,6,8,)

# %%
len(numb)
# Out:
# 9

# %%
range(9)
# Out:
# range(0, 9)

# %%
range(0,9,2)
# Out:
# range(0, 9, 2)

# %%
max(numb)
# Out:
# 45

# %%
min(numb)
# Out:
# 1

# %%
var=("hello")

# %%
print(var)
# Out:
# hello

# %%
del(var)

# %%
ord("A")
# Out:
# 65

# %%
chr(78)
# Out:
# 'N'

# %%
a=949

# %%
a= 749

# %%
a
# Out:
# 749

# %%
(isinstance, a , int)
# Out:
# (<function isinstance(obj, class_or_tuple, /)>, 749, 7399)

# %%
a= 10

# %%
isinstance(a,int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 isinstance(a,int)
#
# TypeError: isinstance() arg 2 must be a type, a tuple of types, or a union

# %%
figure= ("12,45,6,7,8,77,95")

# %%
sorted(figure)
# Out:
# [',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  '1',
#  '2',
#  '4',
#  '5',
#  '5',
#  '6',
#  '7',
#  '7',
#  '7',
#  '8',
#  '9']

# %%
sorted (figure, reverse = True)
# Out:
# ['9',
#  '8',
#  '7',
#  '7',
#  '7',
#  '6',
#  '5',
#  '5',
#  '4',
#  '2',
#  '1',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',']

# %%
names= ("aayushi ,raut, arush ")

# %%
tuple(enumerate(names))
# Out:
# ((0, 'a'),
#  (1, 'a'),
#  (2, 'y'),
#  (3, 'u'),
#  (4, 's'),
#  (5, 'h'),
#  (6, 'i'),
#  (7, ' '),
#  (8, ','),
#  (9, 'r'),
#  (10, 'a'),
#  (11, 'u'),
#  (12, 't'),
#  (13, ','),
#  (14, ' '),
#  (15, 'a'),
#  (16, 'r'),
#  (17, 'u'),
#  (18, 's'),
#  (19, 'h'),
#  (20, ' '))

# %%
name= ("aayushi")

# %%
tuple(enumerate(name))
# Out:
# ((0, 'a'), (1, 'a'), (2, 'y'), (3, 'u'), (4, 's'), (5, 'h'), (6, 'i'))

# %%
l1=(1,2,4,6,7)
l2=("white, black , blue , grey")

# %%
tuple(zip(l1,l2))
# Out:
# ((1, 'w'), (2, 'h'), (4, 'i'), (6, 't'), (7, 'e'))

# %%
all(l1)
# Out:
# True

# %%
any(l2)
# Out:
# True

# %%
7**7
# Out:
# 823543

# %%
sum(l1)
# Out:
# 20

# %%
second=(2,3,6,8,9,6)

# %%
2 in second
# Out:
# True

# %%
a=("Aayushi")

# %%
b=a

# %%
b is a
# Out:
# True

# %%
c=( " bat,ball")

# %%
d= ( " bat,ball")

# %%
c is d
# Out:
# False
