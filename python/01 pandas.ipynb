# %%
import pandas as pd

# %%
df1=pd.read_csv("C:\\Users\\DELL\\Downloads\\22. messy_sales_data.csv")

# %%
df=df1.copy()

# %%
df.head()
# Out:
#     OrderID CustomerID          CustomerName       City    Category  \
# 0  ORD51058  CUST04879        Chaitanya Mane  bangalore     Grocery
# 1  ORD70248  CUST00177         Siddharth Sha      DELHI      SPORTS
# 2  ORD43804  CUST04537  Nathaniel Chatterjee    chennai  electronic
# 3  ORD46367  CUST07605     pranit contractor    Jaipur     Clothing
# 4  ORD32922  CUST03180    Hemang Chakraborty    Amdavad   FURNITURE
#
#    PaymentMode    Price  Quantity  DiscountPct  Rating    OrderDate  \
# 0  net_banking   904.48       3.0           10     3.3   2023-04-24
# 1  Net Banking  1823.76       4.0           20     5.0   04-01-2023
# 2          Upi   770.67       1.0            0     4.9   11/17/2024
# 3          COD  2028.06       1.0            0     2.9          NaN
# 4           cc   604.00       4.0           10     3.7  14 Jan 2023
#
#    CustomerAge                             Email       Phone  \
# 0         29.0          chaitanya.mane@gmail.com  9454663439
# ...

# %%
df.tail()
# Out:
#          OrderID CustomerID        CustomerName       City    Category  \
# 106570  ORD49057  CUST01636            MAX OM      chennai   FURNITURE
# 106571  ORD60012  CUST01826        CHARAN MANNE       pune        Toys
# 106572  ORD78050  CUST04033         Isaiah Wali      DELHI   Furniture
# 106573  ORD68225  CUST04602    Ladli Nazareth    AHMEDABAD  electronic
# 106574  ORD72531  CUST07969           Yatin Rao    Chennai       Sport
#
#              PaymentMode       Price  Quantity  DiscountPct  Rating  \
# 106570        debit card  Rs.1961.37       4.0            0     5.0
# 106571  Cash on Delivery  Rs.1468.22       2.0           20     3.3
# 106572        Debit Card      414.94       2.0           10     3.3
# 106573        DEBIT CARD      916.52       1.0           25     4.6
# 106574        DEBIT CARD      891.46       2.0            5     4.3
#
#           OrderDate  CustomerAge                    Email       Phone  \
# ...

# %%
df.shape
# Out:
# (106575, 15)

# %%
df.size
# Out:
# 1598625

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106575 entries, 0 to 106574
# Data columns (total 15 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   OrderID       106575 non-null  object
#  1   CustomerID    106575 non-null  object
#  2   CustomerName  106575 non-null  object
#  3   City          104481 non-null  object
#  4   Category      106575 non-null  object
#  5   PaymentMode   103332 non-null  object
#  6   Price         106575 non-null  object
#  7   Quantity      106575 non-null  float64
#  8   DiscountPct   106575 non-null  int64
#  9   Rating        100129 non-null  float64
#  10  OrderDate     102358 non-null  object
#  11  CustomerAge   106575 non-null  float64
#  12  Email         99176 non-null   object
#  13  Phone         98117 non-null   object
#  14  ReviewText    93200 non-null   object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 12.2+ MB

# %%
df.describe()
# Out:
#             Quantity    DiscountPct         Rating    CustomerAge
# count  106575.000000  106575.000000  100129.000000  106575.000000
# mean        2.066817       9.382125       3.409874      39.678893
# std         1.387769       9.176865       1.306731      19.263288
# min        -5.000000       0.000000       0.500000       0.000000
# 25%         1.000000       0.000000       2.600000      28.000000
# 50%         2.000000      10.000000       3.300000      38.000000
# 75%         3.000000      20.000000       4.100000      47.000000
# max         5.000000      25.000000       9.900000     150.000000

# %%
df.columns
# Out:
# Index(['OrderID', 'CustomerID', 'CustomerName', 'City', 'Category',
#        'PaymentMode', 'Price', 'Quantity', 'DiscountPct', 'Rating',
#        'OrderDate', 'CustomerAge', 'Email', 'Phone', 'ReviewText'],
#       dtype='object')

# %%
df.dtypes
# Out:
# OrderID          object
# CustomerID       object
# CustomerName     object
# City             object
# Category         object
# PaymentMode      object
# Price            object
# Quantity        float64
# DiscountPct       int64
# Rating          float64
# OrderDate        object
# CustomerAge     float64
# Email            object
# Phone            object
# ReviewText       object
# dtype: object

# %%
df.isnull().sum()
# Out:
# OrderID             0
# CustomerID          0
# CustomerName        0
# City             2094
# Category            0
# PaymentMode      3243
# Price               0
# Quantity            0
# DiscountPct         0
# Rating           6446
# OrderDate        4217
# CustomerAge         0
# Email            7399
# Phone            8458
# ReviewText      13375
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(45232)

# %%
df.City
# Out:
# 0         bangalore
# 1             DELHI
# 2           chennai
# 3           Jaipur
# 4           Amdavad
#             ...
# 106570      chennai
# 106571         pune
# 106572        DELHI
# 106573    AHMEDABAD
# 106574      Chennai
# Name: City, Length: 106575, dtype: object

# %%
df["City"].nunique()
# Out:
# 56

# %%
df["Category"].nunique()
# Out:
# 35

# %%
df["City"].value_counts()
# Out:
# City
# hyderabad     2652
# Jaipur        2651
# JAIPUR        2635
# LUCKNOW       2634
# Jaipur        2631
#  Hyderabad    2628
#  Lucknow      2602
# Hyderabad     2585
# Lucknow       2575
# jaipur        2569
# HYDERABAD     2562
# lucknow       2547
# Ahmedabad     2134
# Poona         2129
# pune          2124
# Amdavad       2110
# Pune          2093
# PUNE          2086
# ahmedabad     2085
# amdavad       2082
# poona         2012
# AHMEDABAD     1994
# CALCUTTA      1833
# madras        1816
# Madras        1807
# chennai       1805
# Calcutta      1792
# Chennai       1791
# Kolkata       1755
# KOLKATA       1753
# kolkata       1739
# CHENNAI       1728
# calcutta      1672
# MADRAS        1663
# banglore      1557
# bangalore     1549
# New Delhi     1526
# Bangalore     1517
# NEW DELHI     1517
# bengaluru     1488
# BANGALORE     1481
# new delhi     1473
# Bengaluru     1462
# DELHI         1456
# delhi         1448
# Delhi         1444
# Banglore      1436
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(1056)

# %%
df["col1"]=df["PaymentMode"]

# %%
df.head()
# Out:
#     OrderID CustomerID          CustomerName       City    Category  \
# 0  ORD51058  CUST04879        Chaitanya Mane  bangalore     Grocery
# 1  ORD70248  CUST00177         Siddharth Sha      DELHI      SPORTS
# 2  ORD43804  CUST04537  Nathaniel Chatterjee    chennai  electronic
# 3  ORD46367  CUST07605     pranit contractor    Jaipur     Clothing
# 4  ORD32922  CUST03180    Hemang Chakraborty    Amdavad   FURNITURE
#
#    PaymentMode    Price  Quantity  DiscountPct  Rating    OrderDate  \
# 0  net_banking   904.48       3.0           10     3.3   2023-04-24
# 1  Net Banking  1823.76       4.0           20     5.0   04-01-2023
# 2          Upi   770.67       1.0            0     4.9   11/17/2024
# 3          COD  2028.06       1.0            0     2.9          NaN
# 4           cc   604.00       4.0           10     3.7  14 Jan 2023
#
#    CustomerAge                             Email       Phone  \
# 0         29.0          chaitanya.mane@gmail.com  9454663439
# ...

# %%
df.sample()
# Out:
#        OrderID CustomerID  CustomerName       City Category PaymentMode  \
# 42516  ORD5548  CUST03915  Peter Shenoy  Ahmedabad  grocery         Upi
#
#          Price  Quantity  DiscountPct  Rating   OrderDate  CustomerAge  \
# 42516  1368.43       1.0           10     3.6  12-04-2024         18.0
#
#                              Email       Phone         ReviewText col1
# 42516  peter.shenoy@rediffmail.com  9655251564  delivery was late  Upi

# %%
df.isnull().sum()
# Out:
# OrderID             0
# CustomerID          0
# CustomerName        0
# City             2094
# Category            0
# PaymentMode      3243
# Price               0
# Quantity            0
# DiscountPct         0
# Rating           6446
# OrderDate        4217
# CustomerAge         0
# Email            7399
# Phone            8458
# ReviewText      13375
# col1             3243
# dtype: int64

# %%
df.DiscountPct.mean().round(3)*10
# Out:
# np.float64(93.82)

# %%
df.isna().mean().round(3)*100
# Out:
# OrderID          0.0
# CustomerID       0.0
# CustomerName     0.0
# City             2.0
# Category         0.0
# PaymentMode      3.0
# Price            0.0
# Quantity         0.0
# DiscountPct      0.0
# Rating           6.0
# OrderDate        4.0
# CustomerAge      0.0
# Email            6.9
# Phone            7.9
# ReviewText      12.5
# col1             3.0
# dtype: float64

# %%
df.["Quantity"].mean().round()*100
# Out:
#   Cell In[37], line 1
#     df.["Quantity"].mean().round()*100
#        ^
# SyntaxError: invalid syntax

# %%
df[df["City"].isna()].head()
# Out:
#       OrderID CustomerID      CustomerName City   Category       PaymentMode  \
# 44   ORD60845  CUST00989       LAKSH SAINI  NaN  Clothings               NaN
# 110  ORD20288  CUST01667       BALVEER RAM  NaN      Books                dc
# 130  ORD42875  CUST07659      Arjun Shukla  NaN       toys  cash on delivery
# 177  ORD14310  CUST07857  Lavanya Bhargava  NaN  furniture               upi
# 195  ORD97450  CUST04620     Harrison Gala  NaN  Clothing        CREDIT CARD
#
#           Price  Quantity  DiscountPct  Rating    OrderDate  CustomerAge  \
# 44      1312.67       4.0           10     2.6  12 Mar 2024         35.0
# 110      344.35       2.0            0     3.3   11/02/2024         25.0
# 130      953.44       5.0           25     4.3  10 Dec 2024         47.0
# 177  Rs.1575.61       1.0            0     3.4   09/18/2023         22.0
# 195      873.31       1.0            5     1.2   2023-05-14         36.0
#
#                             Email           Phone  \
# ...

# %%
df[df["Category"].isna()].head()
# Out:
# Empty DataFrame
# Columns: [OrderID, CustomerID, CustomerName, City, Category, PaymentMode, Price, Quantity, DiscountPct, Rating, OrderDate, CustomerAge, Email, Phone, ReviewText, col1]
# Index: []

# %%
df["City"]=df["City"].fillna("Unknown")

# %%
df["City"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Price"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["PaymentMode"].isnull().sum()
# Out:
# np.int64(3243)

# %%
df["PaymentMode"]=df["PaymentMode"].fillna(df["PaymentMode"].mode()[0])

# %%
df["PaymentMode"].isnull().sum()
# Out:
# np.int64(0)

# %%
df[df.duplicated(keep=False)]
# Out:
#          OrderID CustomerID     CustomerName      City     Category  \
# 81      ORD61902  CUST03914     Yash Sawhney  Calcutta         Book
# 121     ORD19515  CUST03317    Balendra Lata    madras       beauty
# 130     ORD42875  CUST07659     Arjun Shukla   Unknown         toys
# 174     ORD97258  CUST04413    Jatin Borra        Pune          Toy
# 230     ORD88850  CUST05230       Falan Bumb   Lucknow      GROCERY
# ...          ...        ...              ...       ...          ...
# 106224  ORD20702  CUST04842      Turvi Lad     kolkata         toys
# 106266  ORD57327  CUST06398        Sai Misra    JAIPUR        BOOKS
# 106399  ORD52908  CUST00065        Darsh Rau   LUCKNOW  ELECTRONICS
# 106434  ORD17717  CUST00227   ZAYYAN SRIDHAR  CALCUTTA    furniture
# 106560  ORD68829  CUST01971    AARAV BOBAL      Bombay       Beauty
#
#              PaymentMode      Price  Quantity  DiscountPct  Rating  \
# 81                  UPI     1090.48       3.0            5     3.5
# ...

# %%
df[df.duplicated(keep=False)].sort_values("OrderID").head()
# Out:
#          OrderID CustomerID   CustomerName       City Category PaymentMode  \
# 12509   ORD10011  CUST05549  Dominic Nadig     Mumbai  grocery  Debit Card
# 46621   ORD10011  CUST05549  Dominic Nadig     Mumbai  grocery  Debit Card
# 54945  ORD100260  CUST08013    Krisha Mann  bangalore    Sport          CC
# 19142  ORD100260  CUST08013    Krisha Mann  bangalore    Sport          CC
# 77714  ORD100271  CUST01032     SIYA BORAH    Chennai  GROCERY          cc
#
#          Price  Quantity  DiscountPct  Rating   OrderDate  CustomerAge  \
# 12509   986.17       2.0           10     1.1  09/23/2023         31.0
# 46621   986.17       2.0           10     1.1  09/23/2023         31.0
# 54945   492.31       1.0           25     5.0  05/07/2023         36.0
# 19142   492.31       1.0           25     5.0  05/07/2023         36.0
# 77714  4020.00       1.0           20     1.6  02/12/2023         18.0
#
#                            Email       Phone                   ReviewText
# ...

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (105519, 15)

# %%
df["OrderID"].duplicated().sum()
# Out:
# np.int64(519)

# %%
df["Category"].duplicated().sum()
# Out:
# np.int64(105484)

# %%
df["Email"].duplicated().sum()
# Out:
# np.int64(66168)

# %%
dup_order_ids= df[df.["OrderID"].duplicated(keep=False)].sort_values("OrderID")

# %%
df["CustomerName"].unique()[1:35000:100]
# Out:
# array(['Siddharth Sha', 'Indali Kala', 'Chandresh Sarma', 'nikita kade',
#        'Wahab Agarwal', 'Saksham Jaggi', 'Jacob Prabhu', 'Abeer Golla',
#        'ayushman chander', '  Brijesh Mander  ', 'Rajata Gala',
#        ' Shravya Kala', 'Priya Hora', 'Nidhi Sinha', 'vrishti sharaf',
#        'Shivani Rajagopalan', '  Idika Mohanty  ', 'ADVIKA MITTAL',
#        'Chavvi Gade', 'LILA REDDY', '  Fariq Sridhar  ',
#        '  Damini Suri  ', 'Omya Karpe', 'Maanav De', 'Jasmit Mukherjee',
#        'Rachana Bail', ' Theodore Krish', 'Triveni Pal',
#        '  Sudiksha Nayar  ', '  Anika Warrior  ', '  Manan Nath  ',
#        ' AASHI AHUJA', 'Yatin Ramesh', 'saumya dave', 'Alka Nagi',
#        'Ojas Anne', 'Hiral Dey', 'yashica palla', ' Raksha Buch',
#        'Bimala Dube', 'Eesha Singhal', 'SHAURYA KRISH',
#        '  aradhana ratta  ', 'Panini Goda', 'Om Minhas', ' LUCKY PRAKASH',
#        'Wyatt Tella', '  Pooja Ganguly  ', ' Shaurya Sarna',
# ...

# %%
df["CustomerName"].str.strip().str.title()
# Out:
# 0               Chaitanya Mane
# 1                Siddharth Sha
# 2         Nathaniel Chatterjee
# 3            Pranit Contractor
# 4           Hemang Chakraborty
#                   ...
# 106570                  Max Om
# 106571            Charan Manne
# 106572             Isaiah Wali
# 106573          Ladli Nazareth
# 106574               Yatin Rao
# Name: CustomerName, Length: 105519, dtype: object

# %%
df["New_Names"]=df["CustomerName"].str.strip().str.title()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19772\577085235.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["New_Names"]=df["CustomerName"].str.strip().str.title()

# %%
df["New_City"]=df["City"].str.strip().str.title()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19772\2707740040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["New_City"]=df["City"].str.strip().str.title()

# %%
df["New_City"]
# Out:
# 0         Bangalore
# 1             Delhi
# 2           Chennai
# 3            Jaipur
# 4           Amdavad
#             ...
# 106570      Chennai
# 106571         Pune
# 106572        Delhi
# 106573    Ahmedabad
# 106574      Chennai
# Name: New_City, Length: 105519, dtype: object
