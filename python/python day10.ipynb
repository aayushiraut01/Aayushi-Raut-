# %%
row=1
while row<=5:
    num=1
    while num<=row:
        print(row, end="")
        num=num+1
    print()
    row=row+1
# Out:
# 1
# 22
# 333
# 4444
# 55555

# %% [raw]
# row=1
# while ro

# %%
row=5
while row >=1:
    num=1
    while num<=row:
        print(num,end="")
        num=num+1
    print()
    row=row-1
# Out:
# 12345
# 1234
# 123
# 12
# 1

# %%
row=5
while row>=1:
    num=5
    while num>=row:
        print(num,end="")
        num=num-1
    print()
    row=row-1
# Out:
# 5
# 54
# 543
# 5432
# 54321

# %%
row = 5

while row >= 1:
    num = 5

    while num >= row:
        print(num, end="")
        num = num - 1

    print()
    row = row - 1
# Out:
# 5
# 54
# 543
# 5432
# 54321

# %%
row=1
while row<=5:
    num=1
    while num<=row:
        print(num,end="")
        num=num+1
    print()
    row=row+1
# Out:
# 1
# 12
# 123
# 1234
# 12345

# %%
row=1
while row<=5:
    num=1
    while num<=row:
        print(row,end="")
        num=num+1
    print()
    row=row+1
# Out:
# 1
# 22
# 333
# 4444
# 55555

# %%
row=5
while row >=1:
    num=1
    while num<=row:
        print(row, end="")
        num=num+1
    print()
    row=row-1
# Out:
# 55555
# 4444
# 333
# 22
# 1

# %%
row=5
while row>=1:
    num=row
    while num>=1:
        print(num, end="")
        num=num-1
    print()
    row=row-1
# Out:
# 54321
# 4321
# 321
# 21
# 1

# %%
row = 5

while row >= 1:
    num = 1

    while num <= row:
        print(num, end="")
        num = num + 1

    print()
    row = row - 1
# Out:
# 12345
# 1234
# 123
# 12
# 1

# %%
row=1
while row<=5:
    num=1
    while num<=row:
        print(num, end="")
        num=num+1
    print()
    row= row+1
# Out:
# 1
# 12
# 123
# 1234
# 12345

# %%
row=5
while row>=1:
    num=1
    while num<=row:
        print(num, end="")
        num=num+1
    print()
    row=row-1
# Out:
# 12345
# 1234
# 123
# 12
# 1

# %%
row=5
while row>=1:
    num=5
    while num>=row:
        print(num,end="")
        num=num-1
    print()
    row=row-1
# Out:
# 5
# 54
# 543
# 5432
# 54321

# %%
row=5
while row>=1:
    num=1
    while num<=row:
        print(num,end="")
        num=num+1
    print()
    row=row-1
# Out:
# 12345
# 1234
# 123
# 12
# 1

# %%
row=5
while row>=1:
    num=5
    while num>=row:
        print(num,end="")
        num=num-1
    print()
    row=row-1
# Out:
# 5
# 54
# 543
# 5432
# 54321

# %%
ord("A")
# Out:
# 65

# %%
ord("E")
# Out:
# 69

# %%
row=1
while row<=5:
    num=65
    while num<=64+row:
        print(chr(num),end="")
        num=num+1
    print()
    row=row+1
# Out:
# A
# AB
# ABC
# ABCD
# ABCDE

# %%
ord("a")
# Out:
# 97

# %%
ord("e")
# Out:
# 101

# %%
row=1
while row<=5:
    num=97
    while num<=97+row:
        print(chr(num), end="")
        num=num+1
    print()
    row=row+1
# Out:
# ab
# abc
# abcd
# abcde
# abcdef
