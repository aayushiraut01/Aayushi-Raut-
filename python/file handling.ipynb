# %%
f =open("test.txt", "w")

# %%
f.write ("this is my first file")
# Out:
# 21

# %%
f.close()

# %%
f.close()

# %%
f = open("test.txt")

# %%
f.read()
# Out:
# 'this is my first filenew file'

# %%
f.close()

# %%
f= open("text.txt", "w")

# %%
f.write(" this is my newer version of jupyter notebook ")
# Out:
# 46

# %%
f.close()

# %%
f=open("test.txt")

# %%
f.read()
# Out:
# 'this is my first filenew file'

# %%
f.close()

# %%
with open ("test.txt" , "r")  as f:
    print (f.read())
    f.close
# Out:
# this is my first filenew file

# %%
f = open("test.txt")

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\DELL'

# %%
os.listdir('C:\\Users\\DELL')
# Out:
# ['.anaconda',
#  '.conda',
#  '.continuum',
#  '.copilot',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.ms-ad',
#  '.vscode',
#  '.vscode-shared',
#  'anaconda3',
#  'anaconda_projects',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'half string.ipynb',
#  'Links',
#  'Local Settings',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{0a6b2f85-8f41-11f1-9c08-e126c8d886e6}.TM.blf',
#  'NTUSER.DAT{0a6b2f85-8f41-11f1-9c08-e126c8d886e6}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{0a6b2f85-8f41-11f1-9c08-e126c8d886e6}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'PrintHood',
#  'python day 2 .ipynb',
#  'python day 3.ipynb',
#  'python day 4.ipynb',
#  'python day 7.ipynb',
#  'python day 8.ipynb',
#  'python day 9.ipynb',
#  'python day1.ipynb',
#  'python day6.ipynb',
# ...

# %%
os.mkdir("nation")

# %%
os.rmdir("nation")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\DELL'

# %%
f=open("test")
