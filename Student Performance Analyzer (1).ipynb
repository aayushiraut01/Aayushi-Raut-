# %% [markdown]
# # Student Performance Analyzer

# %%
name= input("Enter student name:")

maths= int(input("Enter Maths marks:"))
science= int(input("Enter Science marks:"))
english= int(input("Enter English marks:"))

total = maths + science + english 
average = total/3

print(" Students Name:", name)
print("Total Marks:", total)
print("Averge:",average)
# Out:
# Enter student name: Arush
# Enter Maths marks: 90
# Enter Science marks: 80
# Enter English marks: 70
#  Students Name: Arush
# Total Marks: 240
# Averge: 80.0

# %%
if average >=40:
    print("Result: pass")
else:
    print("Result: Fail")
# Out:
# Result: pass

# %%
if average>=90:
    print("grade: A+")
elif average>=75:
    print("grade: A")
elif average>=60:
    print("grade: B")
elif average>=40:
    print("grade: C")
else:
    print("grade:F")
# Out:
# grade: A

# %%
percentage =(total/300)*100
print("Percentage:", percentage)
# Out:
# Percentage: 80.0

# %%
if percentage >=90:
    print("Performance : Excellent")
elif percentage >=80:
    print("Performance : Very Good")
elif percentag >=70:
    print("Performance : Good")
elif percentage >=60:
    print("Performace : Needs improvement")
else:
    print("Performance : poor")
# Out:
# Performance : Very Good

# %%
highest_subject= "Maths"
highest_marks = maths

if science> highest_marks:
    highest_subject= "Science"
    highest_marks= science

if english> highest_marks:
    highest_subject= "English"
    highest_marks= english

print("Highest scoring subject:", highest_subject)
print("Highest Marks:", highest_marks)
# Out:
# Highest scoring subject: Maths
# Highest Marks: 90

# %%
lowest_subject= "English"
lowest_marks= english

if maths< lowest_marks:
    lowest_subject= "Maths"
    lowest_marks= maths

if science< lowest_marks:
    lowest_subject= "Science"
    lowest_marks= science

print("Lowest scoring subject:", lowest_subject)
print("Lowest Marks:", lowest_marks)
# Out:
# Lowest scoring subject: English
# Lowest Marks: 70

# %%
print("---------------------------------------------")
print("               STUDENT REPORT                ")
print("---------------------------------------------")

print("Student Name:", name)
print("Total Marks:", total)
print("Average Marks:", average)
print("Percentage:", percentage)

if average>=40:
    result= "pass"
else:
    result = "fail"
print("Result:", result)

if average >=90:
    grade= "A+"
elif average>= 75:
    grade = "A"
elif average >=60:
    grade = "B"
elif average >=40:
    grade = "C"
else:
    grade = "F"

print("Grade:", grade)

print("Highest Scoring Subject:", highest_subject)
print("Highest Marks:", highest_marks)

print("Lowest Scoring Subject:", lowest_subject)
print("Lowest Marks:", lowest_marks)

print("------------------------------------------------")
# Out:
# ---------------------------------------------
#                STUDENT REPORT
# ---------------------------------------------
# Student Name: Arush
# Total Marks: 240
# Average Marks: 80.0
# Percentage: 80.0
# Result: pass
# Grade: A
# Highest Scoring Subject: Maths
# Highest Marks: 90
# Lowest Scoring Subject: English
# Lowest Marks: 70
# ------------------------------------------------
