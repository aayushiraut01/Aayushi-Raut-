# %%
class person:
    def __init__(self,name,proffession,dob):
        self.name=name
        self.proffession=proffession
        self.dob=dob

# %%
obj=person("Rahul","CA","9/6/2003")

# %%
obj.name
# Out:
# 'Rahul'

# %%
obj.proffession
# Out:
# 'CA'

# %%
class person:
    company="TCS"
    def __init__(self,name,proffession,dob):
        self.name=name
        self.proffession=proffession
        self.dob=dob

# %%
obj=person("Amit","Btech","4/6/2003")

# %%
obj.proffession
# Out:
# 'Btech'

# %%
sentence="I love coding in Python"
sanitization=sentence.replace(" ","_")
print(sanitization)
# Out:
# I_love_coding_in_Python

# %%
row=5
for i in range(5,0,-1):
    for j in range (i,0,-1):
        print(j,end=" ")
    print()
# Out:
# 5 4 3 2 1
# 4 3 2 1
# 3 2 1
# 2 1
# 1
