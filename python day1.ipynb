# %%
name= "aayushi raut"

# %%
age= "22"

# %%
height= "5.4"

# %%
print(name)
# Out:
# aayushi raut

# %%
print(age)
# Out:
# 22

# %%
print(height)
# Out:
# 5.4

# %%
datatype= " integer, float, string, boolean, complex"

# %%
integer= (1,2,3,4,5,6,7,8,9)

# %%
print(type(integer))
# Out:
# <class 'tuple'>

# %%
float=(1.11, 2.11, 3.11)

# %%
print(type(float))
# Out:
# <class 'tuple'>

# %%
string= (" data science")

# %% [raw]
# print(type(string))

# %%
print(type(string))
# Out:
# <class 'str'>

# %%
boolean= ("passed")

# %%
print(boolean)
# Out:
# passed

# %%
print(type(boolean))
# Out:
# <class 'str'>

# %%
boolean=("false")

# %%
print(boolean)
# Out:
# false

# %%
print(type(boolean))
# Out:
# <class 'str'>

# %%
age= ("22")

# %%
print(age)
# Out:
# 22

# %%
complex= 7+3j

# %%
print(complex)
# Out:
# (7+3j)

# %%
print(type(complex))
# Out:
# <class 'complex'>

# %%
z=7+3j

# %%
print(z)
# Out:
# (7+3j)

# %%
print(type(z))
# Out:
# <class 'complex'>

# %%
z1= 7+3j
z2= 2+5J

# %%
print(z1+z2)
# Out:
# (9+8j)

# %%
print(z1*z2)
# Out:
# (-1+41j)

# %%
z= 7 + 3j

# %%
print(z.real)
# Out:
# 7.0

# %%
print(z.imag)
# Out:
# 3.0

# %%
data_structure= ("list, tuple, set , dictionary")

# %%
list=(" apple, banana , cheeku")

# %%
colours=( "blue", "orange", "pink")

# %%
print(colours)
# Out:
# ('blue', 'orange', 'pink')

# %%
print(type(list))
# Out:
# <class 'str'>

# %%
print(list)
# Out:
#  apple, banana , cheeku

# %%
fruits= ("apple , banana")

# %%
print(fruits)
# Out:
# apple , banana

# %%
fruits=("aaple, banana, mango")

# %%
print(fruits)
# Out:
# aaple, banana, mango

# %%
print(type(fruits))
# Out:
# <class 'str'>

# %%
fruits=("apple", "banana")

# %%
print(type(fruits))
# Out:
# <class 'tuple'>

# %%
fruits=["orange"," yellow"," blue"]

# %%
print(type(fruits))
# Out:
# <class 'list'>

# %%
set={"ball", "bat"}

# %%
print(type(set))
# Out:
# <class 'set'>

# %%
list=[1,2,3,4,5]

# %%
print(type(list))
# Out:
# <class 'list'>

# %%
dress=("tops", "jeanse")

# %%
print(type(dress))
# Out:
# <class 'tuple'>

# %%
colours={"yellow", "blue"}

# %%
print(type(colours))
# Out:
# <class 'set'>

# %%
dictionary= {"1": "white", "2":"grey", "3":"pink"}

# %%
print(type(dictionary))
# Out:
# <class 'dict'>

# %% [markdown]
# #

# %%
l1={"1":"apple", "2":"banana"}

# %%
type(l1)
# Out:
# dict
